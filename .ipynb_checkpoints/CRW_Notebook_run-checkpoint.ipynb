# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
from io import BytesIO
import os

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import streamlit as st
from streamlit import session_state

from datetime import datetime
import warnings

# %% [markdown]
# # Download content part B

# %%
import pandas as pd
from openpyxl import load_workbook

# Charger le fichier Excel
fichier = "save/EEPA Tool v28 23 Feb 2023.xlsx"  # remplace par le chemin réel
wb = load_workbook(fichier, data_only=True)

# Filtrer les feuilles "PartB"
feuilles_partb = [nom for nom in wb.sheetnames if nom.startswith("PartB_")]

# Récupérer les cellules H17 à H20 non vides dans chaque feuille
resultats = []
for feuille in feuilles_partb:
    ws = wb[feuille]
    Question = int(feuille.split("Q")[1])
    Pillar = int(ws["D12"].value.split(" ")[1][0])
    resultats.append({"Q": Question , "idx": 'Pillar', "val": Pillar})
    resultats.append({"Q": Question , "idx": 'Definition', "val": ws["D14"].value})
    resultats.append({"Q": Question , "idx": 'Title',  "val": ws["E15"].value})
    i = 0
    for row in range(17, 36):  # H17 à H20
        valeur = ws[f"H{row}"].value
        if valeur is not None:
            i+=1
            resultats.append({"Q": Question , "idx": i, "val": valeur})

# Convertir en DataFrame
df = pd.DataFrame(resultats)
df
# Out:
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\reader\drawings.py:33: UserWarning: DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.
#   warn("DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.")
#       Q         idx                                                val
# 0     1      Pillar                                                  1
# 1     1  Definition                                Strategic Alignment
# 2     1       Title  Has the government assessed the benefits of an...
# 3     1           1  There is no clear understanding about the pros...
# 4     1           2  The pros and cons of an insurance program have...
# ..   ..         ...                                                ...
# 355  45           1  There is no placement of government agency ris...
# 356  45           2  Placement of (re)insurance with risk financing...
# 357  45           3  Placement of (re)insurance with risk financing...
# 358  45           4  Placement of (re)insurance with risk financing...
# 359  45           5  LEVEL 4 PLUS The placement of (re)insurance wi...
#
# [360 rows x 3 columns]

# %%
"Pillar 1: Institutional Readiness"
"This pillar assesses policy alignment and program governance."
"Pillar 2: Data Readiness"
"This pillar assesses your progress towards collating and analysing data to inform program options."
"Pillar 3: Operational Readiness"
"This pillar assesses progress towards developing and using service and administration infrastructure required for a program."
"Pillar 4: Insurance Market Readiness"
"This pillar assesses your progress towards implementing the most appropriate risk financing options for the program."

# %%
dfb = df.pivot(index = 'Q', columns="idx" , values= "val").reset_index()
dfb.head()
# df1.to_excel('')
# Out:
# idx  Q                                                  1  \
# 0    1  There is no clear understanding about the pros...
# 1    2  Broader agendas (e.g., disaster risk managemen...
# 2    3  A set of strategic Disaster Risk Financing (DR...
# 3    4  The scope of participation (i.e., which govern...
# 4    5  The program is not supported by legislation/re...
#
# idx                                                  2  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been acknowledged ...
# 2    A set of strategic DRF objectives have been id...
# 3    The scope of participating agencies and asset ...
# 4    The program falls within general government po...
#
# idx                                                  3  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been acknowledged ...
# 2    A set of strategic DRF objectives have been id...
# 3    The scope of participating agencies/assets has...
# 4    Legislation/regulation specifically refers to ...
#
# idx                                                  4  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been fully integra...
# 2    A set of strategic DRF objectives have been id...
# 3    There is a systematic approach to agency or as...
# 4    Legislation/regulation specifically refers to ...
#
# idx                                                  5            Definition  \
# 0    The pros and cons of an insurance program have...   Strategic Alignment
# 1    Broader policy agendas have been reviewed and,...   Strategic Alignment
# 2    A set of strategic DRF objectives have been id...   Strategic Alignment
# 3    There is a systematic approach to agency or as...  Policy & Legislation
# 4    Legislation/regulation specifically refers to ...  Policy & Legislation
#
# idx Pillar                                              Title
# 0        1  Has the government assessed the benefits of an...
# 1        1  Are insurance program objectives aligned with ...
# 2        1  Have specific program objectives been identifi...
# 3        1  Have you decided which parts of government wil...
# 4        1  Is there a legislation/regulation framework fo...

# %%
dfa = pd.read_excel("content.xlsx")

# %%
with pd.ExcelWriter("EEPA_content.xlsx", engine="openpyxl") as writer:
    dfa.to_excel(writer, sheet_name="Part_A", index=False)
    dfb.to_excel(writer, sheet_name="Part_B", index=False)

# %%
dfa = pd.read_excel("EEPA_content.xlsx", sheet_name= 'Part_A')
dfb = pd.read_excel("EEPA_content.xlsx", sheet_name= 'Part_B')

# %%
dfb.loc[0,[1,2,3,4,5]].tolist()
dfb.loc[0,"Pillar"]
# Out:
# 1

# %%
Dict_Content = pd.read_excel("EEPA_content.xlsx", sheet_name= None)
dfp = Dict_Content['Pillars']
dfa = Dict_Content['Part_A'].set_index('Q')
dfb = Dict_Content['Part_B']

# %%
dfp.loc[0].tolist()
# Out:
# [1,
#  'Pillar 1: Institutional Readiness',
#  'This pillar assesses policy alignment and program governance. ']

# %%
import pandas as pd
from openpyxl import load_workbook

# 3. Réécrire le sheet dans le même fichier
with pd.ExcelWriter("EEPA_content.xlsx", 
                    engine="openpyxl", 
                    mode="a",        # mode append
                    if_sheet_exists="replace"  # remplace l’onglet existant
                   ) as writer:
    # Nécessaire si pandas < 1.3 pour récupérer le workbook :
    # writer.book = load_workbook("mon_fichier.xlsx")
    dfb.to_excel(writer, sheet_name="Part_B", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 5
#       2 from openpyxl import load_workbook
#       4 # 3. Réécrire le sheet dans le même fichier
# ----> 5 with pd.ExcelWriter("EEPA_content.xlsx",
#       6                     engine="openpyxl",
#       7                     mode="a",        # mode append
#       8                     if_sheet_exists="replace"  # remplace l’onglet existant
#       9                    ) as writer:
#      10     # Nécessaire si pandas < 1.3 pour récupérer le workbook :
#      11     # writer.book = load_workbook("mon_fichier.xlsx")
#      12     dfb.to_excel(writer, sheet_name="Part_B", index=False)
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\io\excel\_base.py:1263, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1259 self._handles = IOHandles(
#    1260     cast(IO[bytes], path), compression={"compression": None}
#    1261 )
#    1262 if not isinstance(path, ExcelWriter):
# -> 1263     self._handles = get_handle(
#    1264         path, mode, storage_options=storage_options, is_text=False
#    1265     )
#    1266 self._cur_sheet = None
#    1268 if date_format is None:
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'EEPA_content.xlsx'

# %% [markdown]
# # Test feature streamlit

# %% [markdown]
# dfa.to_dict(orient = 'tight')

# %%
def Init_data():
    data = {}    
    data['idx_menu'] = 0
    Dict_Content = pd.read_excel("EEPA_content.xlsx", sheet_name= None)

    dfp=  Dict_Content['Pillars'].set_index('idx')
    dfa = Dict_Content['Part_A'].set_index('Q').assign(Res=np.NaN)
    dfb = Dict_Content['Part_B'].assign(Res=np.NaN)

    lenA = dfa.index.nunique()
    lenB = dfb.index.nunique()
    dfa['idx'] = np.arange(lenA)
    dfb['idx'] = np.arange(lenA + lenB)


    data= dict(
        dfa = dfa,
        dfb = dfb,
        dfp = dfp, 
        LenA = lenA,
        lenB = lenB, 
        lenTot = lenA + lenB
    )
    
    return data


data = Init_data()
for k,v in data.items():
    if type(v) == pd.DataFrame: 
        print(k, "df")
    else : 
        print(k, v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 28
#      16     data= dict(
#      17         dfa = dfa,
#      18         dfb = dfb,
#    (...)
#      22         lenTot = lenA + lenB
#      23     )
#      25     return data
# ---> 28 data = Init_data()
#      29 for k,v in data.items():
#      30     if type(v) == pd.DataFrame:
#
# Cell In[50], line 12, in Init_data()
#      10 lenA = dfa.index.nunique()
#      11 lenB = dfb.index.nunique()
# ---> 12 dfa['idx'] = np.arange(lenA)
#      13 dfb['idx'] = np.arange(lenA + lenb)
#      16 data= dict(
#      17     dfa = dfa,
#      18     dfb = dfb,
#    (...)
#      22     lenTot = lenA + lenB
#      23 )
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\core\frame.py:5039, in DataFrame._sanitize_column(self, value)
#    5036     return _reindex_for_setitem(value, self.index)
#    5038 if is_list_like(value):
# -> 5039     com.require_length_match(value, self.index)
#    5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (5) does not match length of index (22)

# %%
lenA = data['lenA']
lenB = data['lenB']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 lenA = data['lenA']
#       2 lenB = data['lenB']
#
# KeyError: 'lenA'

# %%
dfaSize = dfa[dfa.Reponse.notnull()].groupby('Q').size()
d = {}

for i in range(lenA + lenB):
    if i < lenA : 
            data['Q' +str(i+1)] = [None] * 4
    else : 
            data['Q' +str(i+1)] = [None] * 2

for Q, s in enumerate(dfaSize):
    data['Q' +str(i+1)]= s

# %%
dfa = data['dfa'].copy()
dfb = data['dfb'].copy()
dfa

dfa.Res.notnull().sum() + dfb.Res.notnull().sum()
# Out:
# 0

# %%
dfa2 = dfa.loc[4]
dfa2
# Out:
#    Pillar  Level                                            Content Reponse
# Q
# 4       1      1  Who is responsible for paying for the repair o...     NaN
# 4       1      2  Costs are fully funded by the national government  yes/no
# 4       1      2  Costs are fully funded by the subnational gove...  yes/no
# 4       1      2  Costs are shared between the national governme...  yes/no
# 4       1      2  Costs are shared between the national governme...  yes/no
# 4       1      2                                             Other:   other

# %%
for idx, row in dfa2.iterrows():
    Pillar , Level , Content , Reponse = row.tolist()
    if Reponse == "yes/no"
    if pd.notna(Reponse)  : print(Reponse)
# Out:
# yes/no
# yes/no
# yes/no
# yes/no
# other

# %%
Qn = 1
pn = dfa2["Pillar"].iloc[0]
print(pn)
Pillar_List = dfp.loc[pn].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 Qn = 1
# ----> 2 pn = dfa2["Pillar"].iloc[0]
#       3 print(pn)
#       4 Pillar_List = dfp.loc[pn].tolist()
#
# NameError: name 'dfa2' is not defined

# %% [markdown]
# # Test immport from docx

# %%
import pandas as pd
from docx import Document

File  = 'save/EEPA Tool v28 23 Feb 2023.xlsx'
# Charger le document Word
doc = Document("SAVE/EEPA_Tool_Facilitators_Handbook_UR24.docx")

# Liste pour stocker les DataFrames
tables = []

# Parcourir toutes les tables du document
for table in doc.tables:
    data = []
    keys = None
    for i, row in enumerate(table.rows):
        text = [cell.text.strip() for cell in row.cells]
        if i == 0:
            keys = text  # première ligne = entêtes
        else:
            data.append(text)
    df = pd.DataFrame(data, columns=keys)
    tables.append(df)

# Affichage du nombre de tableaux extraits
print(f"{len(tables)} tableaux extraits.")

# Exemple : afficher le premier tableau
print(tables[0])
# Out:
# 4 tableaux extraits.
#                                             Question  \
# 0  This column is a replication of the questions ...
#
#                                  Facilitator Context  \
# 0  This column provides additional context that h...
#
#                                  Facilitator’s Notes
# 0  This column is left blank and allows the facil...

# %%
import pandas as pd
import re

# Charger uniquement la feuille PartA
file_path = 'save/EEPA Tool v28 23 Feb 2023.xlsx'
df = pd.read_excel(file_path, sheet_name='PartA', header=None)

# Se concentrer à partir de la cellule F21
start_row = 20  # index 0-based donc 21 -> 20
start_col = 5   # F est la 6ème colonne donc 5 en index Python

# Extraire toutes les questions de la colonne F à partir de la ligne 21
questions = df.iloc[start_row:, start_col]

# Filtrer uniquement les lignes qui commencent par (a), (b), (c), etc.
pattern = r"^\([a-zA-Z]\)"  # regex qui capture (a), (b), etc.

resultats = []
for idx, question in questions.dropna().items():
    if re.match(pattern, str(question).strip()):
        resultats.append({
            'Numéro de question': question[:3],  # par exemple (a)
            'Texte de la question': question[3:].strip()  # le reste du texte après (a)
        })

# Transformer en DataFrame
questions_df = pd.DataFrame(resultats)

# Afficher ou sauvegarder
print(questions_df)

# Sauvegarde dans un fichier si besoin
questions_df.to_excel('save/questions_partA.xlsx', index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# C:\Users\egos\AppData\Local\Temp\ipykernel_42000\2279387805.py:33: UserWarning: Pandas requires version '3.0.3' or newer of 'xlsxwriter' (version '3.0.1' currently installed).
#   questions_df.to_excel('save/questions_partA.xlsx', index=False)

# %%
questions_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
path = "EEPA Tool v28 23 Feb 2023.xlsx"
sh = pd.read_excel(path, sheet_name="PartA_Q1") 
sh
# Out:
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN
# 35         NaN         NaN         NaN
# 36         NaN         NaN         NaN
# 37         NaN         NaN         NaN
# 38         NaN         NaN         NaN
# 39         NaN         NaN         NaN
# 40         NaN         NaN         NaN
# 41         NaN         NaN         NaN
#
#                                     Unnamed: 3  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                 Part A: Enabling Environment
# 6                  Part B: Progress Assessment
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10           Pillar 1: Institutional Readiness
# 11                                         NaN
# 12                                   Question:
# 13                                         NaN
# 14                                          1.
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
# 32  Please add any additional information here
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
#
#                                            Unnamed: 4  \
# 0          Public Assets Financial Protection Program
# 1        Enabling Environment and Progress Assessment
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Are public assets owned and administered centr...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                                            Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11                                                NaN         NaN         NaN
# 12                                                NaN         NaN         NaN
# 13                                                NaN         NaN         NaN
# 14                                                NaN         NaN         NaN
# 15                                                NaN         NaN         NaN
# 16                                                NaN         NaN         NaN
# 17                                                NaN         NaN         NaN
# 18                  a.     Assets are owned centrally         NaN         NaN
# 19                                                NaN         NaN         NaN
# 20                                                NaN         NaN         NaN
# 21                b.     Assets are managed centrally         NaN         NaN
# 22                                                NaN         NaN         NaN
# 23                                                NaN         NaN         NaN
# 24  c.     Assets are owned at relevant line minis...         NaN         NaN
# 25                                                NaN         NaN         NaN
# 26                                                NaN         NaN         NaN
# 27  d.     Assets are managed at relevant line min...         NaN         NaN
# 28                                                NaN         NaN         NaN
# 29                                                NaN         NaN         NaN
# 30                                                NaN         NaN         NaN
# 31                                                NaN         NaN         NaN
# 32                                                NaN         NaN         NaN
# 33                                                NaN         NaN         NaN
# 34                                                NaN         NaN         NaN
# 35                                                NaN         NaN         NaN
# 36                                                NaN         NaN         NaN
# 37                                                NaN         NaN         NaN
# 38                                                NaN         NaN         NaN
# 39                                                NaN         NaN         NaN
# 40                                                NaN         NaN         NaN
# 41                                                NaN         NaN         NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 42  Unnamed: 43  \
# 0          NaN         NaN  ...          NaN          NaN
# 1          NaN         NaN  ...          NaN          NaN
# 2          NaN         NaN  ...          NaN          NaN
# 3          NaN         NaN  ...          NaN          NaN
# 4          NaN         NaN  ...          NaN          NaN
# 5          NaN         NaN  ...          NaN          NaN
# 6          NaN         NaN  ...          NaN          NaN
# 7          NaN         NaN  ...          NaN          NaN
# 8          NaN         NaN  ...          NaN          NaN
# 9          NaN         NaN  ...          NaN          NaN
# 10         NaN         NaN  ...          NaN          NaN
# 11         NaN         NaN  ...          NaN          NaN
# 12         NaN         NaN  ...          NaN          NaN
# 13         NaN         NaN  ...          NaN          NaN
# 14         NaN         NaN  ...          NaN          NaN
# 15         NaN         NaN  ...          NaN          NaN
# 16         NaN         NaN  ...          NaN          NaN
# 17         NaN         NaN  ...          NaN          NaN
# 18         NaN         NaN  ...          NaN          NaN
# 19         NaN         NaN  ...          NaN          NaN
# 20         NaN         NaN  ...          NaN          NaN
# 21         NaN         NaN  ...          NaN          NaN
# 22         NaN         NaN  ...          NaN          NaN
# 23         NaN         NaN  ...          NaN          NaN
# 24         NaN         NaN  ...          NaN          NaN
# 25         NaN         NaN  ...          NaN          NaN
# 26         NaN         NaN  ...          NaN          NaN
# 27         NaN         NaN  ...          NaN          NaN
# 28         NaN         NaN  ...          NaN          NaN
# 29         NaN         NaN  ...          NaN          NaN
# 30         NaN         NaN  ...          NaN          NaN
# 31         NaN         NaN  ...          NaN          NaN
# 32         NaN         NaN  ...          NaN          NaN
# 33         NaN         NaN  ...          NaN          NaN
# 34         NaN         NaN  ...          NaN          NaN
# 35         NaN         NaN  ...          NaN          NaN
# 36         NaN         NaN  ...          NaN          NaN
# 37         NaN         NaN  ...          NaN          NaN
# 38         NaN         NaN  ...          NaN          NaN
# 39         NaN         NaN  ...          NaN          NaN
# 40         NaN         NaN  ...          NaN          NaN
# 41         NaN         NaN  ...          NaN          NaN
#
#                              Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0                                    NaN          NaN          NaN
# 1                                    NaN          NaN          NaN
# 2                                    NaN          NaN          NaN
# 3                                    NaN          NaN          NaN
# 4                                    NaN          NaN          NaN
# 5      Pillar 1: Institutional Readiness          NaN          NaN
# 6               Pillar 2: Data Readiness          NaN          NaN
# 7        Pillar 3: Operational Readiness          NaN          NaN
# 8   Pillar 4: Insurance Market Readiness          NaN          NaN
# 9                                    NaN          NaN          NaN
# 10                                   NaN          NaN          NaN
# 11                                   NaN          NaN          NaN
# 12                                   NaN          NaN          NaN
# 13                                   NaN          NaN          NaN
# 14                                   NaN          NaN          NaN
# 15                                   NaN          NaN          NaN
# 16                                   NaN          NaN          NaN
# 17                                   NaN          NaN          NaN
# 18                                   NaN          NaN          NaN
# 19                                   NaN          NaN          NaN
# 20                                   NaN          NaN          NaN
# 21                                   NaN          NaN          NaN
# 22                                   NaN          NaN          NaN
# 23                                   NaN          NaN          NaN
# 24                                   NaN          NaN          NaN
# 25                                   NaN          NaN          NaN
# 26                                   NaN          NaN          NaN
# 27                                   NaN          NaN          NaN
# 28                                   NaN          NaN          NaN
# 29                                   NaN          NaN          NaN
# 30                                   NaN          NaN          NaN
# 31                                   NaN          NaN          NaN
# 32                                   NaN          NaN          NaN
# 33                                   NaN          NaN          NaN
# 34                                   NaN          NaN          NaN
# 35                                   NaN          NaN          NaN
# 36                                   NaN          NaN          NaN
# 37                                   NaN          NaN          NaN
# 38                                   NaN          NaN          NaN
# 39                                   NaN          NaN          NaN
# 40                                   NaN          NaN          NaN
# 41                                   NaN          NaN          NaN
#
#    Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  Unnamed: 51
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
# 10         NaN          NaN          NaN          NaN          NaN
# 11         NaN          NaN          NaN          NaN          NaN
# 12         NaN          NaN          NaN          NaN    Response:
# 13         NaN          NaN          NaN          NaN          NaN
# 14         NaN          NaN          NaN          NaN          NaN
# 15         NaN          NaN          NaN          NaN          NaN
# 16         NaN          NaN          NaN          NaN          NaN
# 17         NaN          NaN          NaN          NaN          NaN
# 18         NaN          NaN          NaN          NaN          NaN
# 19         NaN          NaN          NaN          NaN          NaN
# 20         NaN          NaN          NaN          NaN          NaN
# 21         NaN          NaN          NaN          NaN          NaN
# 22         NaN          NaN          NaN          NaN          NaN
# 23         NaN          NaN          NaN          NaN          NaN
# 24         NaN          NaN          NaN          NaN          NaN
# 25         NaN          NaN          NaN          NaN          NaN
# 26         NaN          NaN          NaN          NaN          NaN
# 27         NaN          NaN          NaN          NaN          NaN
# 28         NaN          NaN          NaN          NaN          NaN
# 29         NaN          NaN          NaN          NaN          NaN
# 30         NaN          NaN          NaN          NaN          NaN
# 31         NaN          NaN          NaN          NaN          NaN
# 32         NaN          NaN          NaN          NaN          NaN
# 33         NaN          NaN          NaN          NaN          NaN
# 34         NaN          NaN          NaN          NaN          NaN
# 35         NaN          NaN          NaN          NaN          NaN
# 36         NaN          NaN          NaN          NaN          NaN
# 37         NaN          NaN          NaN          NaN          NaN
# 38         NaN          NaN          NaN          NaN          NaN
# 39         NaN          NaN          NaN          NaN          NaN
# 40         NaN          NaN          NaN          NaN          NaN
# 41    Previous          NaN          NaN          NaN         Next
#
# [42 rows x 52 columns]
