# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
from io import BytesIO
import os

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import streamlit as st
from streamlit import session_state

from datetime import datetime
import warnings

# %% [markdown]
# # Download content part B

# %%
import pandas as pd
from openpyxl import load_workbook

# Charger le fichier Excel
fichier = "save/EEPA Tool v28 23 Feb 2023.xlsx"  # remplace par le chemin réel
wb = load_workbook(fichier, data_only=True)

# Filtrer les feuilles "PartB"
feuilles_partb = [nom for nom in wb.sheetnames if nom.startswith("PartB_")]

# Récupérer les cellules H17 à H20 non vides dans chaque feuille
resultats = []
for feuille in feuilles_partb:
    ws = wb[feuille]
    Question = int(feuille.split("Q")[1])
    Pillar = int(ws["D12"].value.split(" ")[1][0])
    resultats.append({"Q": Question , "idx": 'Pillar', "val": Pillar})
    resultats.append({"Q": Question , "idx": 'Title',  "val": ws["E15"].value})
    i = 0
    for row in range(17, 36):  # H17 à H20
        valeur = ws[f"H{row}"].value
        if valeur is not None:
            i+=1
            resultats.append({"Q": Question , "idx": i, "val": valeur})

# Convertir en DataFrame
df = pd.DataFrame(resultats)
df
# Out:
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\reader\drawings.py:33: UserWarning: DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.
#   warn("DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.")
#       Q     idx                                                val
# 0     1  Pillar                                                  1
# 1     1   Title  Has the government assessed the benefits of an...
# 2     1       1  There is no clear understanding about the pros...
# 3     1       2  The pros and cons of an insurance program have...
# 4     1       3  The pros and cons of an insurance program have...
# ..   ..     ...                                                ...
# 310  45       1  There is no placement of government agency ris...
# 311  45       2  Placement of (re)insurance with risk financing...
# 312  45       3  Placement of (re)insurance with risk financing...
# 313  45       4  Placement of (re)insurance with risk financing...
# 314  45       5  LEVEL 4 PLUS The placement of (re)insurance wi...
#
# [315 rows x 3 columns]

# %%
"Pillar 1: Institutional Readiness"
"This pillar assesses policy alignment and program governance."
"Pillar 2: Data Readiness"
"This pillar assesses your progress towards collating and analysing data to inform program options."
"Pillar 3: Operational Readiness"
"This pillar assesses progress towards developing and using service and administration infrastructure required for a program."
"Pillar 4: Insurance Market Readiness"
"This pillar assesses your progress towards implementing the most appropriate risk financing options for the program."

# %%
dfb = df.pivot(index = 'Q', columns="idx" , values= "val").reset_index()
dfb.head()
# df1.to_excel('')
# Out:
# idx  Q                                                  1  \
# 0    1  There is no clear understanding about the pros...
# 1    2  Broader agendas (e.g., disaster risk managemen...
# 2    3  A set of strategic Disaster Risk Financing (DR...
# 3    4  The scope of participation (i.e., which govern...
# 4    5  The program is not supported by legislation/re...
#
# idx                                                  2  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been acknowledged ...
# 2    A set of strategic DRF objectives have been id...
# 3    The scope of participating agencies and asset ...
# 4    The program falls within general government po...
#
# idx                                                  3  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been acknowledged ...
# 2    A set of strategic DRF objectives have been id...
# 3    The scope of participating agencies/assets has...
# 4    Legislation/regulation specifically refers to ...
#
# idx                                                  4  \
# 0    The pros and cons of an insurance program have...
# 1    Broader policy agendas have been fully integra...
# 2    A set of strategic DRF objectives have been id...
# 3    There is a systematic approach to agency or as...
# 4    Legislation/regulation specifically refers to ...
#
# idx                                                  5 Pillar  \
# 0    The pros and cons of an insurance program have...      1
# 1    Broader policy agendas have been reviewed and,...      1
# 2    A set of strategic DRF objectives have been id...      1
# 3    There is a systematic approach to agency or as...      1
# 4    Legislation/regulation specifically refers to ...      1
#
# idx                                              Title
# 0    Has the government assessed the benefits of an...
# 1    Are insurance program objectives aligned with ...
# 2    Have specific program objectives been identifi...
# 3    Have you decided which parts of government wil...
# 4    Is there a legislation/regulation framework fo...

# %%
dfa = pd.read_excel("content.xlsx")

# %%
with pd.ExcelWriter("EEPA_content.xlsx", engine="openpyxl") as writer:
    dfa.to_excel(writer, sheet_name="Part_A", index=False)
    dfb.to_excel(writer, sheet_name="Part_B", index=False)

# %%
dfa = pd.read_excel("EEPA_content.xlsx", sheet_name= 'Part_A')
dfb = pd.read_excel("EEPA_content.xlsx", sheet_name= 'Part_B')

# %% [markdown]
# # Test

# %%
import pandas as pd
from docx import Document

File  = 'save/EEPA Tool v28 23 Feb 2023.xlsx'
# Charger le document Word
doc = Document("SAVE/EEPA_Tool_Facilitators_Handbook_UR24.docx")

# Liste pour stocker les DataFrames
tables = []

# Parcourir toutes les tables du document
for table in doc.tables:
    data = []
    keys = None
    for i, row in enumerate(table.rows):
        text = [cell.text.strip() for cell in row.cells]
        if i == 0:
            keys = text  # première ligne = entêtes
        else:
            data.append(text)
    df = pd.DataFrame(data, columns=keys)
    tables.append(df)

# Affichage du nombre de tableaux extraits
print(f"{len(tables)} tableaux extraits.")

# Exemple : afficher le premier tableau
print(tables[0])
# Out:
# 4 tableaux extraits.
#                                             Question  \
# 0  This column is a replication of the questions ...
#
#                                  Facilitator Context  \
# 0  This column provides additional context that h...
#
#                                  Facilitator’s Notes
# 0  This column is left blank and allows the facil...

# %%
import pandas as pd
import re

# Charger uniquement la feuille PartA
file_path = 'save/EEPA Tool v28 23 Feb 2023.xlsx'
df = pd.read_excel(file_path, sheet_name='PartA', header=None)

# Se concentrer à partir de la cellule F21
start_row = 20  # index 0-based donc 21 -> 20
start_col = 5   # F est la 6ème colonne donc 5 en index Python

# Extraire toutes les questions de la colonne F à partir de la ligne 21
questions = df.iloc[start_row:, start_col]

# Filtrer uniquement les lignes qui commencent par (a), (b), (c), etc.
pattern = r"^\([a-zA-Z]\)"  # regex qui capture (a), (b), etc.

resultats = []
for idx, question in questions.dropna().items():
    if re.match(pattern, str(question).strip()):
        resultats.append({
            'Numéro de question': question[:3],  # par exemple (a)
            'Texte de la question': question[3:].strip()  # le reste du texte après (a)
        })

# Transformer en DataFrame
questions_df = pd.DataFrame(resultats)

# Afficher ou sauvegarder
print(questions_df)

# Sauvegarde dans un fichier si besoin
questions_df.to_excel('save/questions_partA.xlsx', index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# C:\Users\egos\AppData\Local\Temp\ipykernel_42000\2279387805.py:33: UserWarning: Pandas requires version '3.0.3' or newer of 'xlsxwriter' (version '3.0.1' currently installed).
#   questions_df.to_excel('save/questions_partA.xlsx', index=False)

# %%
questions_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
path = "EEPA Tool v28 23 Feb 2023.xlsx"
sh = pd.read_excel(path, sheet_name="PartA_Q1") 
sh
# Out:
# c:\Users\egos\anaconda3\envs\base2\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN
# 35         NaN         NaN         NaN
# 36         NaN         NaN         NaN
# 37         NaN         NaN         NaN
# 38         NaN         NaN         NaN
# 39         NaN         NaN         NaN
# 40         NaN         NaN         NaN
# 41         NaN         NaN         NaN
#
#                                     Unnamed: 3  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                 Part A: Enabling Environment
# 6                  Part B: Progress Assessment
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10           Pillar 1: Institutional Readiness
# 11                                         NaN
# 12                                   Question:
# 13                                         NaN
# 14                                          1.
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
# 32  Please add any additional information here
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
#
#                                            Unnamed: 4  \
# 0          Public Assets Financial Protection Program
# 1        Enabling Environment and Progress Assessment
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Are public assets owned and administered centr...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                                            Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11                                                NaN         NaN         NaN
# 12                                                NaN         NaN         NaN
# 13                                                NaN         NaN         NaN
# 14                                                NaN         NaN         NaN
# 15                                                NaN         NaN         NaN
# 16                                                NaN         NaN         NaN
# 17                                                NaN         NaN         NaN
# 18                  a.     Assets are owned centrally         NaN         NaN
# 19                                                NaN         NaN         NaN
# 20                                                NaN         NaN         NaN
# 21                b.     Assets are managed centrally         NaN         NaN
# 22                                                NaN         NaN         NaN
# 23                                                NaN         NaN         NaN
# 24  c.     Assets are owned at relevant line minis...         NaN         NaN
# 25                                                NaN         NaN         NaN
# 26                                                NaN         NaN         NaN
# 27  d.     Assets are managed at relevant line min...         NaN         NaN
# 28                                                NaN         NaN         NaN
# 29                                                NaN         NaN         NaN
# 30                                                NaN         NaN         NaN
# 31                                                NaN         NaN         NaN
# 32                                                NaN         NaN         NaN
# 33                                                NaN         NaN         NaN
# 34                                                NaN         NaN         NaN
# 35                                                NaN         NaN         NaN
# 36                                                NaN         NaN         NaN
# 37                                                NaN         NaN         NaN
# 38                                                NaN         NaN         NaN
# 39                                                NaN         NaN         NaN
# 40                                                NaN         NaN         NaN
# 41                                                NaN         NaN         NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 42  Unnamed: 43  \
# 0          NaN         NaN  ...          NaN          NaN
# 1          NaN         NaN  ...          NaN          NaN
# 2          NaN         NaN  ...          NaN          NaN
# 3          NaN         NaN  ...          NaN          NaN
# 4          NaN         NaN  ...          NaN          NaN
# 5          NaN         NaN  ...          NaN          NaN
# 6          NaN         NaN  ...          NaN          NaN
# 7          NaN         NaN  ...          NaN          NaN
# 8          NaN         NaN  ...          NaN          NaN
# 9          NaN         NaN  ...          NaN          NaN
# 10         NaN         NaN  ...          NaN          NaN
# 11         NaN         NaN  ...          NaN          NaN
# 12         NaN         NaN  ...          NaN          NaN
# 13         NaN         NaN  ...          NaN          NaN
# 14         NaN         NaN  ...          NaN          NaN
# 15         NaN         NaN  ...          NaN          NaN
# 16         NaN         NaN  ...          NaN          NaN
# 17         NaN         NaN  ...          NaN          NaN
# 18         NaN         NaN  ...          NaN          NaN
# 19         NaN         NaN  ...          NaN          NaN
# 20         NaN         NaN  ...          NaN          NaN
# 21         NaN         NaN  ...          NaN          NaN
# 22         NaN         NaN  ...          NaN          NaN
# 23         NaN         NaN  ...          NaN          NaN
# 24         NaN         NaN  ...          NaN          NaN
# 25         NaN         NaN  ...          NaN          NaN
# 26         NaN         NaN  ...          NaN          NaN
# 27         NaN         NaN  ...          NaN          NaN
# 28         NaN         NaN  ...          NaN          NaN
# 29         NaN         NaN  ...          NaN          NaN
# 30         NaN         NaN  ...          NaN          NaN
# 31         NaN         NaN  ...          NaN          NaN
# 32         NaN         NaN  ...          NaN          NaN
# 33         NaN         NaN  ...          NaN          NaN
# 34         NaN         NaN  ...          NaN          NaN
# 35         NaN         NaN  ...          NaN          NaN
# 36         NaN         NaN  ...          NaN          NaN
# 37         NaN         NaN  ...          NaN          NaN
# 38         NaN         NaN  ...          NaN          NaN
# 39         NaN         NaN  ...          NaN          NaN
# 40         NaN         NaN  ...          NaN          NaN
# 41         NaN         NaN  ...          NaN          NaN
#
#                              Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0                                    NaN          NaN          NaN
# 1                                    NaN          NaN          NaN
# 2                                    NaN          NaN          NaN
# 3                                    NaN          NaN          NaN
# 4                                    NaN          NaN          NaN
# 5      Pillar 1: Institutional Readiness          NaN          NaN
# 6               Pillar 2: Data Readiness          NaN          NaN
# 7        Pillar 3: Operational Readiness          NaN          NaN
# 8   Pillar 4: Insurance Market Readiness          NaN          NaN
# 9                                    NaN          NaN          NaN
# 10                                   NaN          NaN          NaN
# 11                                   NaN          NaN          NaN
# 12                                   NaN          NaN          NaN
# 13                                   NaN          NaN          NaN
# 14                                   NaN          NaN          NaN
# 15                                   NaN          NaN          NaN
# 16                                   NaN          NaN          NaN
# 17                                   NaN          NaN          NaN
# 18                                   NaN          NaN          NaN
# 19                                   NaN          NaN          NaN
# 20                                   NaN          NaN          NaN
# 21                                   NaN          NaN          NaN
# 22                                   NaN          NaN          NaN
# 23                                   NaN          NaN          NaN
# 24                                   NaN          NaN          NaN
# 25                                   NaN          NaN          NaN
# 26                                   NaN          NaN          NaN
# 27                                   NaN          NaN          NaN
# 28                                   NaN          NaN          NaN
# 29                                   NaN          NaN          NaN
# 30                                   NaN          NaN          NaN
# 31                                   NaN          NaN          NaN
# 32                                   NaN          NaN          NaN
# 33                                   NaN          NaN          NaN
# 34                                   NaN          NaN          NaN
# 35                                   NaN          NaN          NaN
# 36                                   NaN          NaN          NaN
# 37                                   NaN          NaN          NaN
# 38                                   NaN          NaN          NaN
# 39                                   NaN          NaN          NaN
# 40                                   NaN          NaN          NaN
# 41                                   NaN          NaN          NaN
#
#    Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  Unnamed: 51
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
# 10         NaN          NaN          NaN          NaN          NaN
# 11         NaN          NaN          NaN          NaN          NaN
# 12         NaN          NaN          NaN          NaN    Response:
# 13         NaN          NaN          NaN          NaN          NaN
# 14         NaN          NaN          NaN          NaN          NaN
# 15         NaN          NaN          NaN          NaN          NaN
# 16         NaN          NaN          NaN          NaN          NaN
# 17         NaN          NaN          NaN          NaN          NaN
# 18         NaN          NaN          NaN          NaN          NaN
# 19         NaN          NaN          NaN          NaN          NaN
# 20         NaN          NaN          NaN          NaN          NaN
# 21         NaN          NaN          NaN          NaN          NaN
# 22         NaN          NaN          NaN          NaN          NaN
# 23         NaN          NaN          NaN          NaN          NaN
# 24         NaN          NaN          NaN          NaN          NaN
# 25         NaN          NaN          NaN          NaN          NaN
# 26         NaN          NaN          NaN          NaN          NaN
# 27         NaN          NaN          NaN          NaN          NaN
# 28         NaN          NaN          NaN          NaN          NaN
# 29         NaN          NaN          NaN          NaN          NaN
# 30         NaN          NaN          NaN          NaN          NaN
# 31         NaN          NaN          NaN          NaN          NaN
# 32         NaN          NaN          NaN          NaN          NaN
# 33         NaN          NaN          NaN          NaN          NaN
# 34         NaN          NaN          NaN          NaN          NaN
# 35         NaN          NaN          NaN          NaN          NaN
# 36         NaN          NaN          NaN          NaN          NaN
# 37         NaN          NaN          NaN          NaN          NaN
# 38         NaN          NaN          NaN          NaN          NaN
# 39         NaN          NaN          NaN          NaN          NaN
# 40         NaN          NaN          NaN          NaN          NaN
# 41    Previous          NaN          NaN          NaN         Next
#
# [42 rows x 52 columns]

# %%
sh
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
#
#    Public Asset Financial Protection Program - Enabling Environment Assessment  \
# 0                                           SCORECARD
# 1                                                 NaN
# 2                                            Previous
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
#
#     Unnamed: 2 Unnamed: 3                                         Unnamed: 4  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN       Next                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# 5          NaN        NaN                                                NaN
# 6          NaN        NaN                                        Assesssment
# 7          NaN          1  Which institutions/organisations (at national,...
# 8          NaN          2  What type of asset is each institution/organis...
# 9          NaN          3                                                NaN
# 10         NaN          4                                                NaN
# 11         NaN        NaN                                                NaN
# 12         NaN        NaN                                                NaN
# 13         NaN        NaN                                                NaN
# 14         NaN        NaN                                                NaN
# 15         NaN        NaN                                                NaN
# 16         NaN        NaN                                                NaN
# 17         NaN        NaN                                                NaN
# 18         NaN        NaN                                                NaN
# 19         NaN        NaN                                                NaN
# 20         NaN        NaN                                                NaN
# 21         NaN        NaN                                                NaN
# 22         NaN        NaN                                                NaN
# 23         NaN        NaN                                                NaN
# 24         NaN        NaN                                                NaN
# 25         NaN        NaN                                                NaN
# 26         NaN        NaN                                                NaN
# 27         NaN        NaN                                                NaN
# 28         NaN        NaN                                                NaN
# 29         NaN        NaN                                                NaN
# 30         NaN        NaN                                                NaN
# 31         NaN        NaN                                                NaN
# 32         NaN        NaN                                                NaN
# 33         NaN        NaN                                                NaN
# 34         NaN        NaN                                                NaN
# 35         NaN        NaN                                                NaN
#
#                       Unnamed: 5  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5   Results from your assessment
# 6                  Your response
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                           NaN
#
#                                            Unnamed: 6
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Please identify areas requiring technical support
# 6                      Priority for technical support
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN

# %% [markdown]
# # Run

# %%
# list trigger = 'Actual', 'Forecast','Both'

# update the trigger by countries
Baseline_Trigger_dict = {
                        #'Afghanistan': 'Actual', # exemple
                        }

# update the not IDA countries list
Not_IDA = ['Guatemala']

run_all(Not_IDA,Baseline_Trigger_dict)
